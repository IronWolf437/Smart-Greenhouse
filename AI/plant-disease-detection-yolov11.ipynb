# %% [markdown]
# # **Model initialization - yolov11n**

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')

# %% [markdown]
# # **Model training**

# %%
model.train(data='/media/ironwolf/study/هندسة/مشروع التخرج/AI/data/plant disease detection/Plant diseases detection.v2i.yolov11/data.yaml', epochs=50, imgsz=640, batch=16, workers=2, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.197 🚀 Python-3.12.3 torch-2.7.1+cu118 CUDA:0 (Quadro P3200, 6072MiB)
# ...

# %% [markdown]
# ---

# %% [markdown]
# # **Model testing**

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

model = YOLO('/media/ironwolf/study/هندسة/مشروع التخرج/AI/runs/detect/train/weights/best.pt')

result = model(input("Enter image path: "))

for r in result:
    img = r.plot()
    plt.figure(figsize=(8, 8))
    plt.imshow(img)
    plt.axis('off')
# Out:
# image 1/1 /media/ironwolf/study/هندسة/مشروع التخرج/AI/images/Untitled-design-1.jpg: 640x640 5 powdery mildews, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
